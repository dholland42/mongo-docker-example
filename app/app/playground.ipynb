# %%
from app.models import RequestPayload
from app.data import get_data, get_mongo_client, load_data

# %%
data = get_data(RequestPayload())
client = get_mongo_client()

# %%
load_data(client=client, data=data['results'])

# %%
collection = client['testdb']['testdata']
cursor = collection.find({})

# %%
list(cursor)
# Out:
# [{'_id': ObjectId('67e5b252fdb4e56156200a43'),
#   'fiscal_year': 2025,
#   'award_amount': 350120,
#   'full_study_section': {'srg_code': 'ZCA1',
#    'srg_flex': None,
#    'sra_designator_code': 'RPRB',
#    'sra_flex_code': 'T',
#    'group_code': 'O1',
#    'name': 'Special Emphasis Panel[ZCA1 RPRB-T (O1)]'}},
#  {'_id': ObjectId('67e5b252fdb4e56156200a44'),
#   'fiscal_year': 2025,
#   'award_amount': 272963,
#   'full_study_section': {'srg_code': 'ZCA1',
#    'srg_flex': None,
#    'sra_designator_code': 'RPRB',
#    'sra_flex_code': 'T',
#    'group_code': 'O1',
#    'name': 'Special Emphasis Panel[ZCA1 RPRB-T (O1)]'}},
#  {'_id': ObjectId('67e5b252fdb4e56156200a45'),
#   'fiscal_year': 2025,
#   'award_amount': 527611,
#   'full_study_section': {'srg_code': 'ZCA1',
#    'srg_flex': None,
#    'sra_designator_code': 'RPRB',
#    'sra_flex_code': 'T',
#    'group_code': 'O1',
#    'name': 'Special Emphasis Panel[ZCA1 RPRB-T (O1)]'}},
# ...
